# %%
class Roi_calculator():
    def __init__(self):
        self.total_income = 0
        self.total_expenses = 0
        self.total_investment = 0

    def income(self): # income box
        income = []
        while True:
            try:
                rental_income = income.append(float(input('Rental Income')))
            except ValueError:
                print("\nSorry, I didn't understand that.\n")
                continue
            else:
                break
        while True:
            try:
                misc = income.append(float(input('Misc')))
            except ValueError:
                print("\nSorry, I didn't understand that.\n")
                continue
            else:
                break
        while True:
            try:
                laundry = income.append(float(input('Laundry')))
            except ValueError:
                print("\nSorry, I didn't understand that.\n")
                continue
            else:
                break
        while True:
            try:
                storage = income.append(float(input('Storage')))
            except ValueError:
                print("\nSorry, I didn't understand that.\n")
                continue
            else:
                break
                
        self.total_income = sum(income)
        print(f'Your total monthly income is {self.total_income}.')

    def expenses(self): #expenses box
        expenses = [] # collects all of the inputs to add together later
        util = [] # collects utilities to add together later
        while True:
            try:
                tax = expenses.append(float(input('Taxes')))
            except ValueError:
                print("\nSorry, I didn't understand that.\n")
                continue
            else:
                break
        while True:
            try:
                insurance = expenses.append(float(input('Insurance')))
            except ValueError:
                print("\nSorry, I didn't understand that.\n")
                continue
            else:
                break
        while True:
            try:
                electric = util.append(float(input('Electric')))
            except ValueError:
                print("\nSorry, I didn't understand that.\n")
                continue
            else:
                break
        while True:
            try:
                water = util.append(float(input('Water')))
            except ValueError:
                print("\nSorry, I didn't understand that.\n")
                continue
            else:
                break
        while True:
            try:
                sewer = util.append(float(input('Sewer')))
            except ValueError:
                print("\nSorry, I didn't understand that.\n")
                continue
            else:
                break
        while True:
            try:
                garbage = util.append(float(input('Garbage')))
            except ValueError:
                print("\nSorry, I didn't understand that.\n")
                continue
            else:
                break
        while True:
            try:
                gas = util.append(float(input('Gas')))
            except ValueError:
                print("\nSorry, I didn't understand that.\n")
                continue
            else:
                break
        while True:
            try:
                lawn_snow_care = expenses.append(float(input('Lawn / Snow Care')))
            except ValueError:
                print("\nSorry, I didn't understand that.\n")
                continue
            else:
                break
        while True:
            try:
                hoa_fees = expenses.append(float(input('HOA Fees')))
            except ValueError:
                print("\nSorry, I didn't understand that.\n")
                continue
            else:
                break
        while True:
            try:
                vacancy = expenses.append(float(input('Vacancy')))
            except ValueError:
                print("\nSorry, I didn't understand that.\n")
                continue
            else:
                break
        while True:
            try:
                repairs = expenses.append(float(input('Repairs')))
            except ValueError:
                print("\nSorry, I didn't understand that.\n")
                continue
            else:
                break
        while True:
            try:
                capex = expenses.append(float(input('Capital Expenditures')))
            except ValueError:
                print("\nSorry, I didn't understand that.\n")
                continue
            else:
                break
        while True:
            try:
                property_management = expenses.append(float(input('Property Management')))
            except ValueError:
                print("\nSorry, I didn't understand that.\n")
                continue
            else:
                break
        while True:
            try:
                mortgage = expenses.append(float(input('Mortgage')))
            except ValueError:
                print("\nSorry, I didn't understand that.\n")
                continue
            else:
                break
        
        utilities = expenses.append(sum(util))
        self.total_expenses = sum(expenses)
        print(f'Your total monthly expenses is {self.total_expenses}.')

    def cash_flow(self): # cash flow box
        self.total_cash_flow = (self.total_income - self.total_expenses) * 12
        print(f'Your annual cash flow is {self.total_cash_flow}.')

    def investment(self): # investment box
        investment = [] #collects inputs to add together later
        while True:
            try:
                down_payment = investment.append(float(input('Down Payment')))
            except ValueError:
                print("\nSorry, I didn't understand that.\n")
                continue
            else:
                break
        while True:
            try:
                closing_costs = investment.append(float(input('Closing Costs')))
            except ValueError:
                print("\nSorry, I didn't understand that.\n")
                continue
            else:
                break
        while True:
            try:
                rehab_budget = investment.append(float(input('Rehab Budget')))
            except ValueError:
                print("\nSorry, I didn't understand that.\n")
                continue
            else:
                break
        while True:
            try:
                misc_other = investment.append(float(input('Misc Other')))
            except ValueError:
                print("\nSorry, I didn't understand that.\n")
                continue
            else:
                break
        
        

        self.total_investment = sum(investment)
        print(f'Your total investment is {self.total_investment}.')

    def roi(self):
        # annual_cash_flow = (self.total_investment * 12)
        cash_on_cash_roi = ((self.total_cash_flow / self.total_investment) * 100)
        print(f'Your cash on cash ROI is {cash_on_cash_roi}%.')
    
    def runner(self):
        while True:
            user_ = input('Please fill in the following sections to the best of your ability. [S] to get started or [Q] to quit.').lower()
            if user_ == 's':
                self.income()
                self.expenses()
                self.cash_flow()
                self.investment()
                self.roi()
                break
            elif user_ == 'q':
                break
            else:
                'I\'m sorry. That is an invail input. Please try again.'

user_ = Roi_calculator()
user_.runner()
# Out:
# Your total monthly income is 2000.0.
# Your total monthly expenses is 1610.0.
# Your annual cash flow is 4680.0.
# Your total investment is 50000.0.
# Your cash on cash ROI is 9.36%.
